# %% [markdown]
# ## Chargement des données pour Laverie 1

# %%
import pandas as pd
import os

# %%
base_path = "./Data/laverie1"
l1_transactions_transaction = pd.read_csv(
    os.path.join(base_path, "transactions_transaction.csv"),
    sep=";",  # Essaie aussi ",", "\t", "|" selon le fichier
)

# %%
l1_transactions_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6622 entries, 0 to 6621
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   N° Transaction            6621 non-null   float64
#  1   Date/Heure(Europe/Paris)  6621 non-null   object
#  2   Type                      6621 non-null   object
#  3   Details                   6621 non-null   object
#  4   Selection                 6611 non-null   float64
#  5   Description               6612 non-null   object
#  6   Pièce                     6622 non-null   object
#  7   Billet                    6622 non-null   int64
#  8   Carte bancaire            6622 non-null   object
#  9   Fidélitée                 6622 non-null   int64
#  10  Prix                      6622 non-null   object
#  11  Insérée                   6622 non-null   object
#  12  Rendue                    6622 non-null   object
# dtypes: float64(2), int64(2), object(9)
# ...

# %%
l1_transactions_transaction.head()
# Out:
#    N° Transaction Date/Heure(Europe/Paris)       Type Details  Selection  \
# 0         65707.0      2025-06-30 11:54:59  Démarrage       *       11.0
# 1         65706.0      2025-06-30 11:53:57  Démarrage       *       14.0
# 2         65705.0      2025-06-30 11:19:17  Démarrage       *       34.0
# 3         65704.0      2025-06-30 11:18:32  Démarrage       *       33.0
# 4         65703.0      2025-06-30 11:17:18  Démarrage       *       15.0
#
#      Description Pièce  Billet Carte bancaire  Fidélitée Prix Insérée Rendue
# 0   Machine 8 kg     0       0            4,5          0  4,5     4,5      0
# 1  Machine 16 kg     0       0              9          0    9       9      0
# 2      Lessive       0       0            1,2          0  1,2     1,2      0
# 3     Détachant      0       0            1,2          0  1,2     1,2      0
# 4  Machine 16 kg     0       0              9          0    9       9      0

# %%
l1_transactions_transaction.columns
# Out:
# Index(['N° Transaction', 'Date/Heure(Europe/Paris)', 'Type', 'Details',
#        'Selection', 'Description', 'Pièce', 'Billet', 'Carte bancaire',
#        'Fidélitée', 'Prix', 'Insérée', 'Rendue'],
#       dtype='object')

# %%
l1_transactions_transaction.describe()
# Out:
#        N° Transaction    Selection       Billet  Fidélitée
# count     6621.000000  6611.000000  6622.000000     6622.0
# mean     62397.000000    19.143700     2.706131        0.0
# std       1911.462398     6.149025   110.162898        0.0
# min      59087.000000     0.000000     0.000000        0.0
# 25%      60742.000000    14.000000     0.000000        0.0
# 50%      62397.000000    21.000000     0.000000        0.0
# 75%      64052.000000    22.000000     0.000000        0.0
# max      65707.000000    35.000000  8960.000000        0.0

# %%
l1_transactions_transaction = pd.read_csv(
    os.path.join(base_path, "transactions_transaction.csv"),
    sep=";",  # Essaie aussi ",", "\t", "|" selon le fichier
)

# %%
l1_transactions_jour = pd.read_csv(
    os.path.join(base_path, "transactions_jour.csv"),
    sep=";",  
)
l1_transactions_jour.head()
# Out:
#   Date(Europe/Paris) C.A. Esp () C.A. CB () Jeton () Fidelité ()  \
# 0         2025-01-01        20,90       25,00      0,00         0,00
# 1         2025-01-02       103,40      156,90      0,00         0,00
# 2         2025-01-03        74,10      104,20      0,00         0,00
# 3         2025-01-04        86,50      177,20      0,00         0,00
# 4         2025-01-05        58,50      132,60      0,00         0,00
#
#   Remb. () C.A. Tot ()
# 0      0,00        45,90
# 1      0,00       260,30
# 2      0,00       178,30
# 3      0,00       263,70
# 4      0,00       191,10

# %%
l1_remplissages = pd.read_csv(
    os.path.join(base_path, "remplissages.csv"),
    sep=";",  
)
l1_remplissages.head()
# Out:
#   Infos (Europe/Paris) Infos (Europe/Paris).1 Infos (Europe/Paris).2  \
# 0                   N°                   Date                  Heure
# 1                  128             2024-06-17               10:13:05
# 2                  129             2024-06-17               10:15:05
# 3                  130             2024-06-17               10:17:13
# 4                  131             2024-06-17               10:20:03
#
#   Remplissage () Remplissage ().1 Details Remplissage (nombre)  \
# 0           Total        Trop plein                          2 
# 1           12,50              0,00                            0
# 2           36,00              0,00                           18
# 3            3,80              0,00                            0
# 4            2,40              0,00                            0
#
#   Details Remplissage (nombre).1 Details Remplissage (nombre).2  \
# 0                            1                           0.5 
# ...

# %%
l1_remplissages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Infos (Europe/Paris)            12 non-null     object
#  1   Infos (Europe/Paris).1          11 non-null     object
#  2   Infos (Europe/Paris).2          11 non-null     object
#  3   Remplissage ()                 11 non-null     object
#  4   Remplissage ().1               11 non-null     object
#  5   Details Remplissage (nombre)    11 non-null     object
#  6   Details Remplissage (nombre).1  11 non-null     object
#  7   Details Remplissage (nombre).2  11 non-null     object
#  8   Details Remplissage (nombre).3  11 non-null     object
#  9   Details Remplissage (nombre).4  11 non-null     object
#  10  Etat FDC  () *¹                11 non-null     object
#  11  Etat FDC  () *¹.1              11 non-null     object
# dtypes: object(12)
# ...

# %%
l1_remplissages.describe()
# Out:
#        Infos (Europe/Paris) Infos (Europe/Paris).1 Infos (Europe/Paris).2  \
# count                    12                     11                     11
# unique                   12                      6                     11
# top                      N°             2024-06-17                  Heure
# freq                      1                      5                      1
#
#        Remplissage () Remplissage ().1 Details Remplissage (nombre)  \
# count               11                11                           11
# unique              11                 2                            5
# top              Total              0,00                            0
# freq                 1                10                            7
#
#        Details Remplissage (nombre).1 Details Remplissage (nombre).2  \
# count                              11                             11
# unique                              5                              5
# ...

# %%
l1_releves = pd.read_csv(
    os.path.join(base_path, "releves.csv"),
    sep=";",  
)
l1_releves.head()
# Out:
#   Infos (Europe/Paris) Infos (Europe/Paris).1 Infos (Europe/Paris).2  \
# 0                   N°                   Date                  Heure
# 1                   15             2024-10-25               17:07:28
# 2                   16             2024-11-21               15:44:31
# 3                   17             2024-12-13               18:16:44
# 4                   18             2025-01-02               17:00:41
#
#   Pièces () Billets () Chiffre Affaire () Chiffre Affaire ().1  \
# 0      Total       Total                Esp.                  C.B.
# 1     166,00     1120,00             1339,60               1864,70
# 2     446,30     1370,00             1793,60               2821,10
# 3     174,40     1250,00             1404,00               1930,20
# 4     113,10     1180,00             1313,30               1925,00
#
#   Chiffre Affaire ().2 Chiffre Affaire ().3 Chiffre Affaire ().4  \
# 0                 Jeton                Rendu*                 Total
# ...

# %%
l1_releves.columns
# Out:
# Index(['Infos (Europe/Paris)', 'Infos (Europe/Paris).1',
#        'Infos (Europe/Paris).2', 'Pièces ()', 'Billets ()',
#        'Chiffre Affaire ()', 'Chiffre Affaire ().1', 'Chiffre Affaire ().2',
#        'Chiffre Affaire ().3', 'Chiffre Affaire ().4', 'Fidelite ()',
#        'Fidelite ().1', 'FDC ()'],
#       dtype='object')

# %%
l1_alertes = pd.read_csv(
    os.path.join(base_path, "alertes.csv"),
    sep=";",  
)
l1_alertes.head()
# Out:
#                          Export des alertes Bailleul
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Période : 2024/01/01 00:00:00 - 2024/12/31 23:...
# 4                                                NaN

# %% [markdown]
# ## Chargement des données de Laverie 2

# %%
base_path = "./Data/laverie2"
l2_transactions_transaction = pd.read_csv(
    os.path.join(base_path, "transactions_transaction.csv"),
    sep=";",  # Essaie aussi ",", "\t", "|" selon le fichier
)
l2_transactions_transaction.head()
# Out:
#    N° Transaction Date/Heure(Europe/Paris)       Type Details  Selection  \
# 0         40199.0      2025-06-30 12:37:31  Démarrage       *       20.0
# 1         40198.0      2025-06-30 12:37:05  Démarrage       *       20.0
# 2         40197.0      2025-06-30 12:36:20  Démarrage       *       20.0
# 3         40196.0      2025-06-30 11:56:48  Démarrage       *       14.0
# 4         40195.0      2025-06-30 11:18:54  Démarrage       *       20.0
#
#     Description Pièce  Billet Carte bancaire  Fidélitée Prix Insérée Rendue
# 0      Séchoir    2,2       0              0          0  2,2     2,2      0
# 1      Séchoir    2,2       0              0          0  2,2     2,2      0
# 2      Séchoir      0      10              0          0  2,2      10    7,8
# 3  Machine 9 kg     0       5              0          0    5       5      0
# 4      Séchoir      0       0            2,2          0  2,2     2,2      0

# %%
l2_transactions_jour = pd.read_csv(
    os.path.join(base_path, "transactions_jour.csv"),
    sep=";",  
)
l2_transactions_jour.head()
# Out:
#   Date(Europe/Paris) C.A. Esp () C.A. CB () Jeton () Fidelité ()  \
# 0         2025-01-01        10,00       26,00      0,00         0,00
# 1         2025-01-02        61,00      123,00      0,00         0,00
# 2         2025-01-03        45,00       23,00      0,00         0,00
# 3         2025-01-04        38,00      173,00      0,00         0,00
# 4         2025-01-05        36,00      106,00      0,00         0,00
#
#   Remb. () C.A. Tot ()
# 0      0,00        36,00
# 1      0,00       184,00
# 2    -20,00        68,00
# 3      0,00       211,00
# 4      0,00       142,00

# %%
l2_remplissages = pd.read_csv(
    os.path.join(base_path, "remplissages.csv"),
    sep=";",  
)
l2_remplissages.head()
# Out:
#   Infos (Europe/Paris) Infos (Europe/Paris).1 Infos (Europe/Paris).2  \
# 0                   N°                   Date                  Heure
# 1                   18             2024-08-21               08:17:22
# 2                   19             2024-08-21               08:22:21
# 3                   20             2024-09-05               10:13:51
# 4                   21             2024-10-15               09:04:10
#
#   Remplissage () Remplissage ().1 Details Remplissage (nombre)  \
# 0           Total        Trop plein                          2 
# 1            8,10              0,00                            0
# 2           15,00              0,00                            0
# 3          160,10              0,00                           60
# 4           42,90              0,00                           18
#
#   Details Remplissage (nombre).1 Details Remplissage (nombre).2  \
# 0                            1                           0.5 
# ...

# %%
l2_releves = pd.read_csv(
    os.path.join(base_path, "releves.csv"),
    sep=";",  
)
l2_releves.head()
# Out:
#                                 Infos (Europe/Paris) Infos (Europe/Paris).1  \
# 0                                                 N°                   Date
# 1                                                  1             2025-05-14
# 2                                                  2             2025-05-26
# 3  *Les remboursements sont soustraits du Total c...                    NaN
#
#   Infos (Europe/Paris).2 Pièces () Billets () Chiffre Affaire ()  \
# 0                  Heure      Total       Total                Esp.
# 1               14:06:37    5180,50    43090,00            51835,00
# 2               09:05:10      10,00      225,00              278,40
# 3                    NaN        NaN         NaN                 NaN
#
#   Chiffre Affaire ().1 Chiffre Affaire ().2 Chiffre Affaire ().3  \
# 0                  C.B.                 Jeton                Rendu*
# 1              80071,80                  0,00                144,48
# ...

# %%
l2_alertes = pd.read_csv(
    os.path.join(base_path, "alertes.csv"),
    sep=";",  
)
l2_alertes.head()
# Out:
#                Export des alertes Vieux Boulogne-cpy
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Période : 2025/01/01 00:00:00 - 2025/12/31 23:...
# 4                                                NaN

# %%
l2_alertes.columns
# Out:
# Index(['Export des alertes Vieux Boulogne-cpy'], dtype='object')
